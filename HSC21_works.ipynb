# %%
import pandas as pd

# %%
df = pd.read_csv('Brd_Regi_List.csv')
df1 = pd.read_csv('Tort_19_20.csv')

# %%
# marge two file on Reg
dfm =pd.merge(df,df1,on='Reg',how='outer')

# %%
#convert csv new file
dfm.to_csv("final01.csv")

# %%
dfm
# Out:
#        BSL                     Name           Reg Gender Group  \
# 0    253.0      ASMAUL HUSNA PRAPTI  1.517794e+09   FEM.    BS
# 1    254.0  NUZHAT FATIMA BOISHAKHI  1.610879e+09   FEM.    BS
# 2    255.0   MOSSAMAT NUSAIBA ISLAM  1.614200e+09   FEM.    BS
# 3    256.0    SAIMA SHARMIN MONISHA  1.617693e+09   FEM.    BS
# 4    258.0             ZARIN TASNIM  1.617742e+09   FEM.    BS
# ..     ...                      ...           ...    ...   ...
# 297    NaN                      NaN  1.517763e+09    NaN   NaN
# 298    NaN                      NaN  1.617752e+09    NaN   NaN
# 299    NaN                      NaN  1.617805e+09    NaN   NaN
# 300    NaN                      NaN  1.617811e+09    NaN   NaN
# 301    NaN                      NaN  1.617742e+09    NaN   NaN
#
#                 Father Name                 Mother Name   Sub1   Sbu2   Sub2  \
# 0          MD. AHASAN HABIB               SHAMIMA HABIB  239.0  240.0  253.0
# ...

# %%
df2 = pd.read_csv('HSC21_Acc.csv')

# %%
dff =pd.merge(dfm,df2,on='SId',how='outer')

# %%
dff.to_csv("final.csv")

# %%
dff
# Out:
#        BSL                     Name           Reg Gender Group  \
# 0    253.0      ASMAUL HUSNA PRAPTI  1.517794e+09   FEM.    BS
# 1    254.0  NUZHAT FATIMA BOISHAKHI  1.610879e+09   FEM.    BS
# 2    255.0   MOSSAMAT NUSAIBA ISLAM  1.614200e+09   FEM.    BS
# 3    256.0    SAIMA SHARMIN MONISHA  1.617693e+09   FEM.    BS
# 4    258.0             ZARIN TASNIM  1.617742e+09   FEM.    BS
# ..     ...                      ...           ...    ...   ...
# 320    NaN                      NaN           NaN    NaN   NaN
# 321    NaN                      NaN           NaN    NaN   NaN
# 322    NaN                      NaN           NaN    NaN   NaN
# 323    NaN                      NaN           NaN    NaN   NaN
# 324    NaN                      NaN           NaN    NaN   NaN
#
#                 Father Name                 Mother Name   Sub1   Sbu2   Sub2  \
# 0          MD. AHASAN HABIB               SHAMIMA HABIB  239.0  240.0  253.0
# ...
